# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # IF Statements
# ### If and user-defined
# ### ELIF (Else if) to follow (saying do 1, otherwise do the following)
# ### else:  says, here is the last thing to do, then you are finished.

# %%
##Setting path
##Importing script orders_products_merged.pkl
## .pkl do NOT NEED import = True

# %%
path = r'/Users/ECC/Career Foundry/Anaconda Python CF Exercises'
df_orders_prods_merged = pd.read_csv(r'/Users/ECC/Career Foundry/Anaconda Python CF Exercises/02 Data/Prepared Data/orders_products_merged.pkl')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[5], line 2
#       1 path = r'/Users/ECC/Career Foundry/Anaconda Python CF Exercises'
# ----> 2 df_orders_prods_merged = pd.read_csv(r'/Users/ECC/Career Foundry/Anaconda Python CF Exercises/02 Data/Prepared Data/orders_products_merged.pkl')
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
# ...

# %%
path = r'/Users/ECC/Career Foundry/Anaconda Python CF Exercises'
df_orders_prods_merged = pd.read_pkl(r'/Users/ECC/Career Foundry/Anaconda Python CF Exercises/02 Data/Prepared Data/orders_products_merged.pkl')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 path = r'/Users/ECC/Career Foundry/Anaconda Python CF Exercises'
# ----> 2 df_orders_prods_merged = pd.read_pkl(r'/Users/ECC/Career Foundry/Anaconda Python CF Exercises/02 Data/Prepared Data/orders_products_merged.pkl')
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'read_pkl'

# %%
path = r'/Users/ECC/Career Foundry/Anaconda Python CF Exercises'
df_orders_prods_merged = pd.read_pickle(r'/Users/ECC/Career Foundry/Anaconda Python CF Exercises/02 Data/Prepared Data/orders_products_merged.pkl')

# %%
df_orders_prods_merged.head ()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 1             1   2398795        1    prior             2                   3
# 2             2    473747        1    prior             3                   3
# 3             3   2254736        1    prior             4                   4
# 4             4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
# ...

# %%
## Importing pickle pd.read.pickle. Use full pickle, not .pkl
## index = True not needed with .pkl

# %% [markdown]
# # Renaming df for clarity
# ### df = df_orders_products_merged

# %%
df = df_orders_prods_merged

# %%
df.head ()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 1             1   2398795        1    prior             2                   3
# 2             2    473747        1    prior             3                   3
# 3             3   2254736        1    prior             4                   4
# 4             4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
# ...

# %%
df = df [:1000000]

# %%
df.describe ()
# Out:
#        Unnamed: 0_x      order_id         user_id    order_number  \
# count  1.000000e+06  1.000000e+06  1000000.000000  1000000.000000
# mean   1.690835e+06  1.710240e+06   101788.547547       18.731714
# std    9.789667e+05  9.873682e+05    59011.894306       18.563841
# min    0.000000e+00  5.000000e+00        1.000000        1.000000
# 25%    8.429560e+05  8.555392e+05    50641.000000        5.000000
# 50%    1.685566e+06  1.709734e+06   101164.000000       12.000000
# 75%    2.527854e+06  2.565079e+06   152132.000000       27.000000
# max    3.421076e+06  3.421068e+06   206209.000000       99.000000
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# count      1000000.000000     1000000.000000           939915.000000
# mean             2.686741          13.272235               10.646367
# std              2.053382           4.218017                8.467237
# min              0.000000           0.000000                0.000000
# ...

# %%
## Using block of code from example below. 

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
##Sets low prices to 5 or less
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
##Sets mid prices from 5 to 15
  elif row['prices'] > 15:
    return 'High range'
##Sets high to over 15
  else: return 'Not enough data'
##Returns 'Not Enough Data' text when above does not match to any

# %% [markdown]
# ## Testing above code

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/q5/s7f717nj30jblv023rddwlkm0000gn/T/ipykernel_38367/2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df.shape
# Out:
# (1000000, 18)

# %% [markdown]
# ### Defining and applying the above block to our df

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# # If-Statements with the loc() Function
# ### Conditions

# %%
## Copied from exercise

df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product' 
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'
# Out:
# /var/folders/q5/s7f717nj30jblv023rddwlkm0000gn/T/ipykernel_38367/3099113052.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
## error shows (loc) function would be useful, as in line 19
## Ex also tells us to enter each line by line

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
## The loc() function is being called on the df dataframe; Values = “if ‘prices’ column of the df dataframe are greater than 15.”
##After the comma comes the implied “then.” Here, “price_range_loc” is being set equal to the string “High-range product.”

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product' 
## If less than 15 & greater than 5 = Mid-range

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'
## If 5 or less = Low range

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
df.describe ()
# Out:
#        Unnamed: 0_x      order_id         user_id    order_number  \
# count  1.000000e+06  1.000000e+06  1000000.000000  1000000.000000
# mean   1.690835e+06  1.710240e+06   101788.547547       18.731714
# std    9.789667e+05  9.873682e+05    59011.894306       18.563841
# min    0.000000e+00  5.000000e+00        1.000000        1.000000
# 25%    8.429560e+05  8.555392e+05    50641.000000        5.000000
# 50%    1.685566e+06  1.709734e+06   101164.000000       12.000000
# 75%    2.527854e+06  2.565079e+06   152132.000000       27.000000
# max    3.421076e+06  3.421068e+06   206209.000000       99.000000
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# count      1000000.000000     1000000.000000           939915.000000
# mean             2.686741          13.272235               10.646367
# std              2.053382           4.218017                8.467237
# min              0.000000           0.000000                0.000000
# ...

# %%
df.shape
# Out:
# (1000000, 19)

# %%
df_orders_prods_merged.shape
# Out:
# (32404859, 17)

# %%
## I renamed it, so going back to the whole list is now ridiculously long name
## REMEMBER: df_orders_prods_merged.loc[df_orders_prods_merged[prices...]]
## NAMES MUST MATCH

# %%
df_orders_prods_merged.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df_orders_prods_merged.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexing.py:814, in _LocationIndexer.__setitem__(self, key, value)
#     812 else:
#     813     key = com.apply_if_callable(key, self.obj)
# --> 814 indexer = self._get_setitem_indexer(key)
#     815 self._has_valid_setitem_indexer(key)
#     817 iloc = self if self.name == "iloc" else self.obj.iloc
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexing.py:703, in _LocationIndexer._get_setitem_indexer(self, key)
#     699 if isinstance(key, range):
#     700     # GH#45479 test_loc_setitem_range_key
#     701     key = list(key)
# --> 703 return self._convert_to_indexer(key, axis=0)
#
# ...

# %%
df_orders_prods_merged.loc[df_orders_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_orders_prods_merged.loc[(df_orders_prods_merged['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_orders_prods_merged.loc[df_orders_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_orders_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# NaN                   21104410
# Low-range product     10126321
# Mid-range product       756450
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %%
## NaN values still returned.
## Not sure why.
## These should have been removed or filtered out.
## AH! New customers; the NaN values should be for 'previous order' from earler assignments

# %% [markdown]
# # If-Statements with For-Loops
# #### Using ( number, number) will loop through each number listed individually until they have all been processed.
# ####

# %%
for x in range (35, 50):
    print("My age is %d" %(x))
# Out:
# My age is 35
# My age is 36
# My age is 37
# My age is 38
# My age is 39
# My age is 40
# My age is 41
# My age is 42
# My age is 43
# My age is 44
# My age is 45
# My age is 46
# My age is 47
# My age is 48
# My age is 49

# %%
## The last number is where the funciton stops. If you want 50 included, the second number MUST be 51

# %%
df_orders_prods_merged['orders_day_of_the_week'].value_counts(dropna = "False")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'orders_day_of_the_week'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
## NAMING ! ! !

df_orders_prods_merged['orders_day_of_week'].value_counts(dropna = "False")
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
## 0 is Saturday, 4 is Wednesday

# %%
## Copied from exercise

result = []

for value in df_orders_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
## Combining results in df

# %%
df_orders_prods_merged['Busiest day'] = result

# %%
df_orders_prods_merged['Busiest day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: Busiest day, dtype: int64

# %%
## Regularly busy should show an AVERAGE of those days, 
## not the SUM of all days.
## This can be misleading for the client.

# %%
df_orders_prods_merged.shape
# Out:
# (32404859, 19)

# %%
df_orders_prods_merged.head ()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 1             1   2398795        1    prior             2                   3
# 2             2    473747        1    prior             3                   3
# 3             3   2254736        1    prior             4                   4
# 4             4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
# ...

# %% [markdown]
# # Achievement / Task below

# %%
result = []

for value in df_orders_prods_merged["orders_day_of_week"]:

  if value == [0, 1]:
    result.append("Busiest days")
  elif value == [3, 4]:
    result.append("Slowest days")
  else:
    result.append("Regularly busy")
    
## Using the same elif as in 18, where if day 0, 1 are Busiest 
##and 3,4 are Slowest, then rest are Regular

# %%
df_orders_prods_merged.shape
# Out:
# (32404859, 19)

# %%
df_orders_prods_merged.describe ()
# Out:
#        Unnamed: 0_x      order_id       user_id  order_number  \
# count  3.240486e+07  3.240486e+07  3.240486e+07  3.240486e+07
# mean   1.709858e+06  1.710745e+06  1.029372e+05  1.714230e+01
# std    9.864575e+05  9.872988e+05  5.946610e+04  1.753532e+01
# min    0.000000e+00  2.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.556370e+05  8.559470e+05  5.142200e+04  5.000000e+00
# 50%    1.709176e+06  1.711049e+06  1.026160e+05  1.100000e+01
# 75%    2.565919e+06  2.565499e+06  1.543890e+05  2.400000e+01
# max    3.421081e+06  3.421083e+06  2.062090e+05  9.900000e+01
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# count        3.240486e+07       3.240486e+07            3.032876e+07
# mean         2.738867e+00       1.342515e+01            1.110408e+01
# std          2.090077e+00       4.246380e+00            8.779064e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %%
df_orders_prods_merged['Busiest day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: Busiest day, dtype: int64

# %%
df_orders_prods_merged.head ()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 1             1   2398795        1    prior             2                   3
# 2             2    473747        1    prior             3                   3
# 3             3   2254736        1    prior             4                   4
# 4             4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
# ...

# %%
## No difference to earlier. Days did not combime into Busiest or Slowest days
##  NAMES NAMES NAMES ! ! !

df_orders_prods_merged['Busiest days'].value_counts(dropna = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Busiest days'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
result2 = []

for value in df_orders_prods_merged["orders_day_of_week"]:

  if value == [0 or 1]:
    result2.append("Busiest days")
  elif value == [3 or 4]:
    result2.append("Slowest days")
  else:
    result2.append("Regularly busy")

# %%
df_orders_prods_merged['Busiest_days'] = result2

# %%
df_orders_prods_merged.head ()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 1             1   2398795        1    prior             2                   3
# 2             2    473747        1    prior             3                   3
# 3             3   2254736        1    prior             4                   4
# 4             4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
# ...

# %%
df_orders_prods_merged['Busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    32404859
# Name: Busiest_days, dtype: int64

# %%
df_orders_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    32404859
# Name: busiest_days, dtype: int64

# %%
df_orders_prods_merged.describe ()
# Out:
#        Unnamed: 0_x      order_id       user_id  order_number  \
# count  3.240486e+07  3.240486e+07  3.240486e+07  3.240486e+07
# mean   1.709858e+06  1.710745e+06  1.029372e+05  1.714230e+01
# std    9.864575e+05  9.872988e+05  5.946610e+04  1.753532e+01
# min    0.000000e+00  2.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.556370e+05  8.559470e+05  5.142200e+04  5.000000e+00
# 50%    1.709176e+06  1.711049e+06  1.026160e+05  1.100000e+01
# 75%    2.565919e+06  2.565499e+06  1.543890e+05  2.400000e+01
# max    3.421081e+06  3.421083e+06  2.062090e+05  9.900000e+01
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# count        3.240486e+07       3.240486e+07            3.032876e+07
# mean         2.738867e+00       1.342515e+01            1.110408e+01
# std          2.090077e+00       4.246380e+00            8.779064e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %%
## After reviewing other submissions and the OR variable: 

for value in df_orders_prods_merged['orders_day_of_week']:
  if value == 0 or value ==1:
    result2.append('Busiest days')
  elif value == 4 or value == 3:
    result2.append('Slowest days')
  else:
    result2.append('Regularly days')

# %%
df_orders_prods_merged.describe ()
# Out:
#        Unnamed: 0_x      order_id       user_id  order_number  \
# count  3.240486e+07  3.240486e+07  3.240486e+07  3.240486e+07
# mean   1.709858e+06  1.710745e+06  1.029372e+05  1.714230e+01
# std    9.864575e+05  9.872988e+05  5.946610e+04  1.753532e+01
# min    0.000000e+00  2.000000e+00  1.000000e+00  1.000000e+00
# 25%    8.556370e+05  8.559470e+05  5.142200e+04  5.000000e+00
# 50%    1.709176e+06  1.711049e+06  1.026160e+05  1.100000e+01
# 75%    2.565919e+06  2.565499e+06  1.543890e+05  2.400000e+01
# max    3.421081e+06  3.421083e+06  2.062090e+05  9.900000e+01
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# count        3.240486e+07       3.240486e+07            3.032876e+07
# mean         2.738867e+00       1.342515e+01            1.110408e+01
# std          2.090077e+00       4.246380e+00            8.779064e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %%
df_orders_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    32404859
# Name: busiest_days, dtype: int64

# %%
df_orders_prods_merged.head (25)
# Out:
#     Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0              0   2539329        1    prior             1
# 1              1   2398795        1    prior             2
# 2              2    473747        1    prior             3
# 3              3   2254736        1    prior             4
# 4              4    431534        1    prior             5
# 5              5   3367565        1    prior             6
# 6              6    550135        1    prior             7
# 7              7   3108588        1    prior             8
# 8              8   2295261        1    prior             9
# 9              9   2550362        1    prior            10
# 10           144   2968173       15    prior            15
# 11           146   1870022       15    prior            17
# 12           147   1911383       15    prior            18
# 13           150   2715276       15    prior            21
# 14           151    487368       15    prior            22
# ...
