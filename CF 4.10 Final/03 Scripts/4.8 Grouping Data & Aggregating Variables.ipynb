# %% [markdown]
# # 4.8: Grouping Data & Aggregating Variables
# ### Importing, renaming and grouping

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/ECC/Career Foundry/Anaconda Python CF Exercises'
ords_prods_merged = pd.read_pickle(r'/Users/ECC/Career Foundry/Anaconda Python CF Exercises/02 Data/Prepared Data/orders_prods_merged_20_June.pkl')

# %%
df = ords_prods_merged[:1000000]

# %%
df = df.reset_index(drop=True)
## Tried to reset the column names and letting Pandas remove the Unnamed: O_x and O_y
## Below results confirm it did not work
##  Continuing.

# %%
df.head (10)
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 1             1   2398795        1    prior             2                   3
# 2             2    473747        1    prior             3                   3
# 3             3   2254736        1    prior             4                   4
# 4             4    431534        1    prior             5                   4
# 5             5   3367565        1    prior             6                   2
# 6             6    550135        1    prior             7                   1
# 7             7   3108588        1    prior             8                   1
# 8             8   2295261        1    prior             9                   1
# 9             9   2550362        1    prior            10                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# ...

# %%
df.shape
# Out:
# (1000000, 20)

# %% [markdown]
# ### Deleting eval_set
# ### Unnamed: O_x and Unnamed: O_y cannot be deleted or dropped.
# ### Ask for guidance on removing these.

# %%
## eval_set successfully deleted

# %%
df.head()
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             1   2398795        1             2                   3
# 2             2    473747        1             3                   3
# 3             3   2254736        1             4                   4
# 4             4    431534        1             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered _merge  Unnamed: 0_y product_name  aisle_id  department_id  \
# ...

# %%
df = df.drop(['eval_set'], axis=1)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
# ...

# %%
df.shape
# Out:
# (1000000, 17)

# %%
## df.drop worked on removing Unnamed* columns.
## .shape does not match shape in example exercises. can .drop other columns upon review and input from client/tutor.

# %% [markdown]
# # Grouping Data with pandas

# %%
df.groupby('product_name')

# %% [markdown]
# ## Aggregating Data with agg()
# #### Performing a Single Aggregation
# #### Performing Multiple Aggregations
# ####

# %%
df.groupby('department_id').agg({'order_number': ['mean']})

## groups by Dept.ID, then gets MEAN for order_number column 
## df.groupby('department_id').order_number.mean()
## also gives the same result, with no brackets. (see below)
## determine which is 'Best Practice' for your client/employer
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
df.groupby('department_id').order_number.mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
## df.groupby('department_id').agg({'order_number': ['mean']})
## df.groupby('department_id')['order_number'].mean()
## df.groupby('department_id').order_number.mean()

## ALL perform the same function, the results simply look different.

# %%
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# # Aggregating Data with transform()
# ####

# %%
ords_prods_merged['max_order'] = ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)

## First, a new column called “max_order” is created, which will be what stores the maximum order number
## for each user. Then, the ords_prods_merge dataframe is grouped by the “user_id” column. 
## And finally, the transform() function is applied on the “order_number” column with the np.max argument.

## np= the NumPy library! 
## The max() function is a function included within NumPy that finds the max value within a column. 
## Including this as an argument within the transform() function tells Python to “transform the 
## ‘order_number’ column by applying the max() function from the NumPy library.”

# %%
ords_prods_merged.head(20)
# Out:
#     Unnamed: 0_x  order_id  user_id eval_set  order_number  \
# 0              0   2539329        1    prior             1
# 1              1   2398795        1    prior             2
# 2              2    473747        1    prior             3
# 3              3   2254736        1    prior             4
# 4              4    431534        1    prior             5
# 5              5   3367565        1    prior             6
# 6              6    550135        1    prior             7
# 7              7   3108588        1    prior             8
# 8              8   2295261        1    prior             9
# 9              9   2550362        1    prior            10
# 10           144   2968173       15    prior            15
# 11           146   1870022       15    prior            17
# 12           147   1911383       15    prior            18
# 13           150   2715276       15    prior            21
# 14           151    487368       15    prior            22
# ...

# %%
## data matches example exercise
## pd.options.display.max_rows = None
## allows all 100 rows to be displayed
## removing this function in Cell > Current Outputs > Clear

# %% [markdown]
# # Deriving Columns with loc()

# %%
ords_prods_merged.loc[ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
ords_prods_merged.loc[(ords_prods_merged['max_order'] <= 40) & (ords_prods_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
ords_prods_merged.loc[ords_prods_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

## max order > 40 flag as Loyal
## max order <= 40, AND >10 flag as Regular
## max order <= 10, flag as New

# %%
ords_prods_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merged[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %%
## Top 60, no 'Loyal customers' found

# %%
## Exporting .pkl file
## saving script

ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merged_21_June.pkl'))
