# %% [markdown]
# ## Importing, Setting paths

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/ECC/Career Foundry/Anaconda Python CF Exercises'
orders_products_combined = pd.read_pickle(r'/Users/ECC/Career Foundry/Anaconda Python CF Exercises/02 Data/Prepared Data/orders_products_combined.pkl')

# %%
orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           0   2539329        1    prior             1                   2
# 2           0   2539329        1    prior             1                   2
# 3           0   2539329        1    prior             1                   2
# 4           0   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# ...

# %%
orders_products_combined.shape
# Out:
# (32434489, 12)

# %%
path = r'/Users/ECC/Career Foundry/Anaconda Python CF Exercises'
products_checked = pd.read_csv(r'/Users/ECC/Career Foundry/Anaconda Python CF Exercises/02 Data/Prepared Data/products_checked.csv', index_col = False)

# %%
products_checked.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
products_checked.shape
# Out:
# (49672, 6)

# %%
## Looking at both, only the product_id is present.
## Merge using prodict_id as the key

# %%
df_merged = orders_products_combined.merge(products_checked, on = ['product_id'])

# %%
df_merged.head(10)
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0             0   2539329        1    prior             1                   2
# 1             1   2398795        1    prior             2                   3
# 2             2    473747        1    prior             3                   3
# 3             3   2254736        1    prior             4                   4
# 4             4    431534        1    prior             5                   4
# 5             5   3367565        1    prior             6                   2
# 6             6    550135        1    prior             7                   1
# 7             7   3108588        1    prior             8                   1
# 8             8   2295261        1    prior             9                   1
# 9             9   2550362        1    prior            10                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# ...

# %%
df_merged.shape
# Out:
# (32404859, 17)

# %%
## The number of removed columns does NOT match my math 32424489 - 49672 = 32374817
## The .shape also tells me 6+12 = 18.  I have 17
## _merge flag was successful --(both) shows up in the column.

# %%
df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
